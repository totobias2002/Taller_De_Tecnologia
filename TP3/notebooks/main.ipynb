# %% [markdown]
# <h1> Introducción <h1>

# %% [markdown]
# *Mi trabajo consiste en llegar a la conclusion de la marca favorita
# de la mayoria de personas que llenaron el dicho formulario*
#
# * Llenaron el formulario: 30 Personas
#
# * Enlace: https://forms.gle/oFQnN8GbQwyDt1Uv7
#
# * Medio de comunicacion: Discord y WPP

# %%
import pandas as pd
import matplotlib.pyplot as gf1
import matplotlib.pyplot as gf2

data = pd.read_csv("../data/zapas.csv")



x = data['Cual_es_mi_tu_marca_de_ropa_fav'].value_counts().index.tolist()
y = data['Cual_es_mi_tu_marca_de_ropa_fav'].value_counts().tolist()

gf1.bar(x,y)
gf1.title('Marca de ropa fav.')
gf1.xlabel('Marcas')
gf1.ylabel('Cantidad de personas que le gusta esa marca')
gf1.xticks(rotation=90,fontsize=12)
gf1.show()

xx = data['Cual_de_estas_Zapatillas_te_gustan_mas'].value_counts().index.tolist()
yy = data['Cual_de_estas_Zapatillas_te_gustan_mas'].value_counts().tolist()

gf2.bar(xx,yy)
gf2.title('Modelo de Zapatillas')
gf2.xlabel('Zapatillas')
gf2.ylabel('Cantidad de personas que le gusta esas zapatillas')
gf2.xticks(rotation=90,fontsize=12)
gf2.show()

# %% [markdown]
# *1* #
#
#   ![Imagen](https://http2.mlstatic.com/D_NQ_NP_629716-MLM42663133367_072020-O.webp)
# *1* #
#
# ![Imagen](https://www.moovbydexter.com.ar/on/demandware.static/-/Sites-dabra-catalog/default/dwad2a81fa/products/NI_554725-069/NI_554725-069-1.JPG)
# *2* #
#
# ![Imagen](https://cdn-images.farfetch-contents.com/12/96/03/33/12960333_13486531_600.jpg)

# %% [markdown]
# <h2>Conclusión<h2>

# %% [markdown]
# * Llege a la conclusión de que la gente le gusta mas Nike que el resto de las marcas
# * Las zapatillas preferidas de las 3 que puse hubo un empate entre las Nike Air Force 1
# y las Air Jordan 1 Mid
